# %% [markdown]
# # 📊 Analyse Exploratoire des Données - Fashion Store Sales

# %% [markdown]
# ## 1. Structure du fichier

# %% [markdown]
# ### Colonnes et types :

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\lenovo\Documents\Artefect Project\minio-data\fashion_store_sales _ Data Eng.csv')
df.shape
# Out:
# (2253, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sale_date          2253 non-null   object
#  1   item_id            2253 non-null   int64
#  2   sale_id            2253 non-null   int64
#  3   product_id         2253 non-null   int64
#  4   quantity           2253 non-null   int64
#  5   original_price     2253 non-null   float64
#  6   unit_price         2253 non-null   float64
#  7   discount_applied   2253 non-null   float64
#  8   discount_percent   2253 non-null   object
#  9   discounted         2253 non-null   int64
#  10  item_total         2253 non-null   float64
#  11  channel            2253 non-null   object
#  12  channel_campaigns  2253 non-null   object
#  13  total_amount       2028 non-null   float64
#  14  product_name       2253 non-null   object
#  15  category           2253 non-null   object
# ...

# %%
df["quantity"].value_counts(normalize=True) * 100
# Out:
# quantity
# 2    21.526853
# 4    20.461607
# 1    20.195295
# 5    19.751443
# 3    18.064802
# Name: proportion, dtype: float64

# %%
(df.isna().mean() * 100)
# Out:
# sale_date            0.000000
# item_id              0.000000
# sale_id              0.000000
# product_id           0.000000
# quantity             0.000000
# original_price       0.000000
# unit_price           0.000000
# discount_applied     0.000000
# discount_percent     0.000000
# discounted           0.000000
# item_total           0.000000
# channel              0.000000
# channel_campaigns    0.000000
# total_amount         9.986684
# product_name         0.000000
# category             0.000000
# brand                0.000000
# color                0.000000
# size                 0.000000
# catalog_price        0.000000
# cost_price           0.000000
# customer_id          0.000000
# gender               0.000000
# age_range            0.000000
# signup_date          0.000000
# first_name           5.148691
# last_name            2.840657
# email                9.942299
# country              0.000000
# dtype: float64

# %%
df["signup_date"] = pd.to_datetime(df["signup_date"], errors="coerce")
df["sale_date"] = pd.to_datetime(df["sale_date"], errors="coerce")
mask = df["signup_date"] > df["sale_date"]
percentage = mask.mean() * 100
round(percentage, 2)
# Out:
# np.float64(8.21)

# %%
mask = df["cost_price"] > df["catalog_price"]
percentage = mask.mean() * 100
round(percentage, 2)
# Out:
# np.float64(0.0)
