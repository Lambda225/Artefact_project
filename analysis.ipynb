# %%
import pandas as pd

# %% [markdown]
# ## Présentation
# Le jeu de données fourni représente les ventes d’un magasin e-commerce de prêt-à-porter.
# Chaque ligne correspond à un article vendu dans le cadre d’une transaction.
# Le fichier contient 29 colonnes couvrant plusieurs dimensions métier :
# - vente,
# - produit,
# - client,
# - prix et remises,
# - canal de vente. <br>
#
# Le champ sale_date constitue la clé temporelle principale et sera utilisé pour l’ingestion ciblée des données.

# %%
df = pd.read_csv('./minio-data/fashion_store_sales _ Data Eng.csv')
df.sample(5)
# Out:
#        sale_date  item_id  sale_id  product_id  quantity  original_price  \
# 1864  2025-04-24      571      480         385         5           63.23
# 1501  2025-06-15     1474      349         154         4           53.74
# 28    2025-05-27     1785      670         360         1           69.48
# 1650  2025-06-04      332      155          68         4           47.27
# 63    2025-04-23       60      226         428         1           61.22
#
#       unit_price  discount_applied discount_percent  discounted  ...  \
# 1864       63.23              0.00            0.00%           0  ...
# 1501       53.74              0.00            0.00%           0  ...
# 28         69.48              0.00            0.00%           0  ...
# 1650       42.54              4.73           10.00%           1  ...
# 63         61.22              0.00            0.00%           0  ...
#
#       catalog_price cost_price customer_id  gender age_range signup_date  \
# ...

# %%
df.shape
# Out:
# (2253, 29)

# %% [markdown]
# ## Analyse structurelle des données

# %% [markdown]
# Le fichier mélange plusieurs types d’informations dans une seule table :
# #### Informations transactionnelles
# - sale_id
# - item_id
# - sale_date
# - quantity
# - item_total
# - total_amount
# #### Informations produit
# - product_id
# - product_name
# - category
# - brand
# - color
# - size
# #### Informations de prix
# - original_price
# - unit_price
# - catalog_price
# - cost_price
# - discount_applied
# - discount_percent
# - discounted
# Informations client
# - customer_id
# - first_name
# - last_name
# - email
# - gender
# - age_range
# - signup_date
# - country
# #### Informations marketing / canal
# - channel
# - channel_campaigns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sale_date          2253 non-null   object
#  1   item_id            2253 non-null   int64
#  2   sale_id            2253 non-null   int64
#  3   product_id         2253 non-null   int64
#  4   quantity           2253 non-null   int64
#  5   original_price     2253 non-null   float64
#  6   unit_price         2253 non-null   float64
#  7   discount_applied   2253 non-null   float64
#  8   discount_percent   2253 non-null   object
#  9   discounted         2253 non-null   int64
#  10  item_total         2253 non-null   float64
#  11  channel            2253 non-null   object
#  12  channel_campaigns  2253 non-null   object
#  13  total_amount       2028 non-null   float64
#  14  product_name       2253 non-null   object
#  15  category           2253 non-null   object
# ...
